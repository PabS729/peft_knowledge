# %%
pip list
# Out:
# Package                         Version               Editable project location
# ------------------------------- --------------------- ----------------------------------------------------------
# absl-py                         1.0.0
# accelerate                      0.28.0.dev0
# AccessControl                   5.3.1
# Acquisition                     4.10
# affine                          2.3.1
# aiohttp                         3.8.1
# aiohttp-cors                    0.7.0
# aioredis                        2.0.1
# aiosignal                       1.2.0
# alabaster                       0.7.12
# alembic                         1.8.1
# amply                           0.1.5
# aniso8601                       9.0.1
# anndata                         0.8.0
# antlr4-python3-runtime          4.9.3
# anyio                           3.6.1
# appdirs                         1.4.4
# apptools                        5.1.0
# argcomplete                     2.0.0
# ...
